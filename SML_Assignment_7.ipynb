# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52486/SML_2303A52486/blob/main/SML_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **V.Abhinav(2303A52486)**

# %% [markdown]
# 1. Read the data with pandas and find features and target variables
# 2. Plot a graph between features and target
# 3. Find Best fit line using linear regression.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Read the data

data = pd.read_csv('Salary_Data.csv')

# Extract features and target
x = data[['YearsExperience']]
y = data['Salary']

# Create alinear regression model and fit it
model = LinearRegression()
model.fit(x,y)

# Predict values using the model (best fit line)
y_pred = model.predict(x)

# Plot the graph
plt.scatter(x,y,color='orange',label='Actual data')
plt.plot(x,y_pred,color='black',label='Est fit line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %% [markdown]
# **Question 2**

# %% [markdown]
# 1. Read the data with pandas and find features and target variables
# 2. Plot a graph between features and target
# 3. Find Best fit line using linear regression.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Read the data
data = pd.read_excel('xl sheet assignment 7.xlsx')

# Extract features and target
x = data[['Feature 1']]
y = data['Target (Y)']

# Create alinear regression model and fit it
model = LinearRegression()
model.fit(x,y)

# Predict values using the model (best fit line)
y_pre = model.predict(x)

# Plot the graph
plt.scatter(x,y,color='blue',label='Actual data')
plt.plot(x,y_pre,color='yellow',label='Est fit line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %% [markdown]
# **Feature 2**

# %%
# Extract features and target
x = data[['Feature 2']]
y = data['Target (Y)']

# Create alinear regression model and fit it
model = LinearRegression()
model.fit(x,y)

# Predict values using the model (best fit line)
y_pre = model.predict(x)

# Plot the graph
plt.scatter(x,y,color='green',label='Actual data')
plt.plot(x,y_pre,color='blue',label='Est fit line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %% [markdown]
# **Feature 3**

# %%
# Extract features and target
x = data[['Feature 3']]
y = data['Target (Y)']

# Create alinear regression model and fit it
model = LinearRegression()
model.fit(x,y)

# Predict values using the model (best fit line)
y_pre = model.predict(x)

# Plot the graph
plt.scatter(x,y,color='red',label='Actual data')
plt.plot(x,y_pre,color='blue',label='Est fit line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %% [markdown]
# **Feature 4**

# %%
# Extract features and target
x = data[['Feature 4']]
y = data['Target (Y)']

# Create alinear regression model and fit it
model = LinearRegression()
model.fit(x,y)

# Predict values using the model (best fit line)
y_pre = model.predict(x)

# Plot the graph
plt.scatter(x,y,color='black',label='Actual data')
plt.plot(x,y_pre,color='orange',label='Est fit line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Read the data
data = pd.read_excel('xl sheet assignment 7.xlsx')

# Step 2: Extract features and target
x = data[['Feature 1','Feature 2','Feature 3','Feature 4' ]].values
y = data['Target (Y)'].values

# Split the data into training and testing sets (80% training, 20% testing)
x_train, x_test, y_train, y_test = train_test_split(x,  y, test_size=0.2, random_state=42)

# Create a Linear Regression model
model = LinearRegression()

# Train the model using the training data
model.fit(x_train, y_train)

# Make predictions on the testing data
y_pred = model.predict(x_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)

# Coefficients of the model (for each independent variable)
print("Coefficients:", model.coef_)

# Intercept of the model
print("Intercept:", model.intercept_)
# Out:
# Mean Squared Error: 1.2020186561889359
# R-squared: -0.483973649615969
# Coefficients: [ 0.51848447 -0.09018655  0.5932731   2.3145343 ]
# Intercept: 3.6682867762962417
