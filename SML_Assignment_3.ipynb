# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52486/SML_2303A52486/blob/main/SML_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **V.Abhinav (2303A52486)**

# %%
import pandas as pd
import numpy as np
d=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(d)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
print("Mean of each column:")
print(d.mean())
# Out:
# Mean of each column:
# longitude               -119.589200
# latitude                  35.635390
# housing_median_age        28.845333
# total_rooms             2599.578667
# total_bedrooms           529.950667
# population              1402.798667
# households               489.912000
# median_income              3.807272
# median_house_value    205846.275000
# dtype: float64

# %%
columns = ['latitude', 'total_rooms', 'housing_median_age',
'total_bedrooms']
print("Mean Of latitude:")
m1 = d['latitude'].mean()
print(m1)
print("")
print("Mean Of total_rooms:")
print(d['total_rooms'].mean())
print("")
print("Mean Of house_median_age:")
print(d['housing_median_age'].mean())
print("")
print("Mean Of total_bedrooms")
print(d['total_bedrooms'].mean())
# Out:
# Mean Of latitude:
# 35.635389999999994
#
# Mean Of total_rooms:
# 2599.578666666667
#
# Mean Of house_median_age:
# 28.845333333333333
#
# Mean Of total_bedrooms
# 529.9506666666666

# %%
print("variance of each column:")
print(d.var())
print("Variance of latitude:")
S1 = d['latitude'].var()
print(S1)
print("")
print("Variance of total_rooms:")
print(d['total_rooms'].var())
print("")
print("Variance of house_median_age:")
print(d['housing_median_age'].var())
print("")
print("Variance of total_bedrooms:")
print(d['total_bedrooms'].var())
# Out:
# variance of each column:
# longitude             3.979771e+00
# latitude              4.535492e+00
# housing_median_age    1.576380e+02
# total_rooms           4.646583e+06
# total_bedrooms        1.727686e+05
# population            1.062019e+06
# households            1.335338e+05
# median_income         3.439214e+00
# median_house_value    1.279606e+10
# dtype: float64
# Variance of latitude:
# 4.535492278659553
#
# Variance of total_rooms:
# 4646582.611348672
#
# Variance of house_median_age:
# 157.6379575414027
#
# Variance of total_bedrooms:
# 172768.55375080582

# %% [markdown]
# Maximum Likelihood Estimation of latitude

# %%
x = 50
print("Maximum Likelihood Estimation Of latitude:")
print("")
d['result'] = \
(1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np. \
std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[[ 'latitude', 'result']])
# Out:
# Maximum Likelihood Estimation Of latitude:
#
#       latitude    result
# 0        37.37 -0.001189
# 1        34.26 -0.001189
# 2        33.78 -0.001189
# 3        33.82 -0.001189
# 4        36.33 -0.001189
# ...        ...       ...
# 2995     34.42 -0.001189
# 2996     34.06 -0.001189
# 2997     36.30 -0.001189
# 2998     34.10 -0.001189
# 2999     34.42 -0.001189
#
# [3000 rows x 2 columns]

# %%
x = 75
print("Maximum Likelihood Estimation Of latitude:")
print("")
d['result'] = (1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.
std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[[ 'latitude', 'result']])

(1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.
std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[[ 'latitude', 'result']])
# Out:
# Maximum Likelihood Estimation Of latitude:
#
#       latitude    result
# 0        37.37  0.008202
# 1        34.26  0.008202
# 2        33.78  0.008202
# 3        33.82  0.008202
# 4        36.33  0.008202
# ...        ...       ...
# 2995     34.42  0.008202
# 2996     34.06  0.008202
# 2997     36.30  0.008202
# 2998     34.10  0.008202
# 2999     34.42  0.008202
#
# [3000 rows x 2 columns]
#       latitude    result
# 0        37.37  0.008202
# 1        34.26  0.008202
# 2        33.78  0.008202
# 3        33.82  0.008202
# 4        36.33  0.008202
# ...        ...       ...
# 2995     34.42  0.008202
# 2996     34.06  0.008202
# 2997     36.30  0.008202
# 2998     34.10  0.008202
# 2999     34.42  0.008202
#
# [3000 rows x 2 columns]

# %%
x = 80
print("Maximum Likelihood Estimation Of latitude:")
print("")
d['result'] = (1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.
std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[[ 'latitude', 'result']])
# Out:
# Maximum Likelihood Estimation Of latitude:
#
#       latitude    result
# 0        37.37  0.009686
# 1        34.26  0.009686
# 2        33.78  0.009686
# 3        33.82  0.009686
# 4        36.33  0.009686
# ...        ...       ...
# 2995     34.42  0.009686
# 2996     34.06  0.009686
# 2997     36.30  0.009686
# 2998     34.10  0.009686
# 2999     34.42  0.009686
#
# [3000 rows x 2 columns]

# %% [markdown]
# Question 2

# %%
import numpy as np
mu = np.mean(d['latitude'])
sigma = np.var(d['latitude'], ddof=1)
def log_likelihood(x, mu, sigma):
 return -0.5 * (np.log(2 * np.pi * sigma**2) + ((x - mu)**2 /
 sigma**2))
 values = [50, 75, 80]
 log_likelihoods = [log_likelihood(v, mu, sigma) for v in values]
 print("Mean :", mu)
 print("Variance:", sigma)
 print("Log-Likelihoods for values [50, 75, 80]:", log_likelihoods)

# %% [markdown]
# Question 3
#
# Estimate the density of each column of california_housing
# [‘latitude’,total_rooms’,’house_median_age’,’total_bedrooms’] data, For the bins [5, 10, 15, 20].
# and write your observation

# %%
import matplotlib.pyplot as plt
columns = ['latitude', 'total_rooms', 'housing_median_age',
'total_bedrooms']
bins = 5
for column in columns:
  plt.figure(figsize=(10, 6))
  plt.hist(d[column], bins=bins, density=True, alpha=0.6,
  color='orange',edgecolor='black')
  plt.title(f'Density Plot for {column}')
  plt.xlabel(column)
  plt.ylabel('Density')
  plt.grid(True)
  plt.show()

# %%
columns = ['latitude', 'total_rooms', 'housing_median_age',
'total_bedrooms']
bins = 10
for column in columns:
  plt.figure(figsize=(10, 6))
  plt.hist(d[column], bins=bins, density=True, alpha=0.6,
  color='white',edgecolor='black')
  plt.title(f'Density Plot for {column}')
  plt.xlabel(column)
  plt.ylabel('Density')
  plt.grid(True)
  plt.show()

# %%
columns = ['latitude', 'total_rooms', 'housing_median_age',
'total_bedrooms']
bins = 15
for column in columns:
  plt.figure(figsize=(10, 6))
  plt.hist(d[column], bins=bins, density=True, alpha=0.6,
  color='green',edgecolor='black')
  plt.title(f'Density Plot for {column}')
  plt.xlabel(column)
  plt.ylabel('Density')
  plt.grid(True)
  plt.show()

# %%
columns = ['latitude', 'total_rooms', 'housing_median_age',
'total_bedrooms']
bins = 20
for column in columns:
  plt.figure(figsize=(10, 6))
  plt.hist(d[column], bins=bins, density=True, alpha=0.6,
  color='yellow',edgecolor='black')
  plt.title(f'Density Plot for {column}')
  plt.xlabel(column)
  plt.ylabel('Density')
  plt.grid(True)
  plt.show()

# %% [markdown]
# Observations:
#
# Latitude:
# Shows a fairly uniform distribution around the mean latitude.
#
# Total Rooms and Total Bedrooms:
# Concentrated in lower ranges, with fewer properties having a high count.
#
# Housing Median Age:
# Likely clusters in newer properties, with fewer older properties
